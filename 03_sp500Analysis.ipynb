# %%
import pandas as pd

# %%
sp500 = pd.read_csv('sp500.csv')

# %%
sp500
# Out:
#                                                                                                                                                                                                                                sp500
# Symbol Name                   Sector                 Price  Price/Earnings Dividend Yield Earnings/Share 52 Week Low 52 Week High Market Cap   EBITDA      Price/Sales Price/Book                                        SEC Filings
# MMM    3M Company             Industrials            222.89 24.31          2.3328617      7.92           259.77      175.49       138721055226 9048000000  4.3902707   11.34       http://www.sec.gov/cgi-bin/browse-edgar?action...
# AOS    A.O. Smith Corp        Industrials            60.24  27.76          1.1479592      1.7            68.39       48.925       10783419933  601000000   3.5754826   6.35        http://www.sec.gov/cgi-bin/browse-edgar?action...
# ...

# %% [markdown]
# # Price / Earning OR Price / Earning per Share :

# %% [markdown]
# The ratio for valuing a company that measures its current share price relative to its earnings per share (EPS)

# %% [markdown]
# # Dividend Yield :

# %% [markdown]
# Companies pay dividends when they distribute some of their earnings to shareholders.
#
# Dividends can be paid in cash or additional shares of the company's stock

# %% [markdown]
# # Formula :

# %% [markdown]
# Dividend Yield Ratio = Dividend Per Share/Market Value Per Share

# %% [markdown]
# # Earning / Share OR EPS:

# %% [markdown]
# EPS = Net Income / Total Number of Outstanding Share

# %% [markdown]
# -> Outstaning share are those share that are not repurchased

# %% [markdown]
# # Book value :

# %% [markdown]
# Book value/Share = Total Equity/Number of Outstanding Share

# %%
sp500[:3]
# Out:
#                                                                                                                                                                                                             sp500
# Symbol Name            Sector      Price  Price/Earnings Dividend Yield Earnings/Share 52 Week Low 52 Week High Market Cap   EBITDA     Price/Sales Price/Book                                        SEC Filings
# MMM    3M Company      Industrials 222.89 24.31          2.3328617      7.92           259.77      175.49       138721055226 9048000000 4.3902707   11.34       http://www.sec.gov/cgi-bin/browse-edgar?action...
# AOS    A.O. Smith Corp Industrials 60.24  27.76          1.1479592      1.7            68.39       48.925       10783419933  601000000  3.5754826   6.35        http://www.sec.gov/cgi-bin/browse-edgar?action...

# %%
sp500.iloc[[1, 4]] #1st and 4th record
# Out:
#                                                                                                                                                              sp500
# MMM  3M Company  Industrials 222.89 24.31 2.3328617 7.92 259.77 175.49 138721055226 9048000000  4.3902707 11.34  http://www.sec.gov/cgi-bin/browse-edgar?action...
# ABBV AbbVie Inc. Health Care 108.48 19.41 2.4995599 3.29 125.86 60.05  181386347059 10310000000 6.291571  26.14  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %%
sp500[1:4] #get the first 3 records
# Out:
#                                                                                                                                                                    sp500
# MMM 3M Company          Industrials 222.89 24.31 2.3328617 7.92 259.77 175.49 138721055226 9048000000 4.3902707 11.34  http://www.sec.gov/cgi-bin/browse-edgar?action...
# AOS A.O. Smith Corp     Industrials 60.24  27.76 1.1479592 1.7  68.39  48.925 10783419933  601000000  3.5754826 6.35   http://www.sec.gov/cgi-bin/browse-edgar?action...
# ABT Abbott Laboratories Health Care 56.27  22.51 1.9089824 0.26 64.6   42.28  102121042306 5744000000 3.7404804 3.19   http://www.sec.gov/cgi-bin/browse-edgar?action...

# %%
#If we don't know the integer index for a certain row

sp500.iloc[sp500.index.get_loc('ABT')]
# Out:
#                                                                                                                                                               sp500
# ABT Abbott Laboratories Health Care 56.27 22.51 1.9089824 0.26 64.6 42.28 102121042306 5744000000 3.7404804 3.19  http://www.sec.gov/cgi-bin/browse-edgar?action...
